# %%
# !pip install --upgrade --no-deps --force-reinstall kaggle
from google.colab import files
files.upload()
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d jihyeseo/online-retail-data-set-from-uci-ml-repo
# Out:
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/3a/e7/3bac01547d2ed3d308ac92a0878fbdb0ed0f3d41fb1906c319ccbba1bfbc/kaggle-1.5.12.tar.gz (58kB)
#      |████████████████████████████████| 61kB 2.3MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-cp37-none-any.whl size=73053 sha256=1e2b6332f84c945e219609858c9a9173262efac701c8b43241cb3234429dd6e0
#   Stored in directory: /root/.cache/pip/wheels/a1/6a/26/d30b7499ff85a4a4593377a87ecf55f7d08af42f0de9b60303
# Successfully built kaggle
# Installing collected packages: kaggle
#   Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# Successfully installed kaggle-1.5.12
#      <input type="file" id="files-243de5e0-3c04-4ec7-8dbb-b1feb33d946c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-243de5e0-3c04-4ec7-8dbb-b1feb33d946c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading online-retail-data-set-from-uci-ml-repo.zip to /content
#  78% 17.0M/21.8M [00:00<00:00, 23.8MB/s]
# 100% 21.8M/21.8M [00:00<00:00, 25.3MB/s]

# %%
from zipfile import ZipFile
file_name="online-retail-data-set-from-uci-ml-repo.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print("Extraction Done")
# Out:
# Extraction Done

# %%
import pandas as pd
df=pd.read_excel('Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna(subset=['CustomerID'],inplace=True)

# %%
print("No. of duplicates == ",df.duplicated().sum())

# Lets drop Duplicates
df.drop_duplicates(inplace=True)
# Out:
# No. of duplicates ==  5225

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  401604.000000  401604.000000  401604.000000
# mean       12.183273       3.474064   15281.160818
# std       250.283037      69.764035    1714.006089
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13939.000000
# 50%         5.000000       1.950000   15145.000000
# 75%        12.000000       3.750000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df=df[(df['Quantity']>0) & (df['UnitPrice']>0)]

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  392692.000000  392692.000000  392692.000000
# mean       13.119702       3.125914   15287.843865
# std       180.492832      22.241836    1713.539549
# min         1.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   13955.000000
# 50%         6.000000       1.950000   15150.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000    8142.750000   18287.000000

# %%
import datetime as dt
# Remove time from Invoice Date Column and take only date
get_month=lambda x : dt.datetime(x.year,x.month,1)
df['InvoiceMonth']=df['InvoiceDate'].apply(get_month)

# Grouping
grouping=df.groupby('CustomerID')['InvoiceMonth']
df['CohortMonth'] = grouping.transform('min')

# %%
# Get time difference between invoice issued and cohort date
def get_month_int (dframe,column):
    year = dframe[column].dt.year
    month = dframe[column].dt.month
    day = dframe[column].dt.day
    return year, month , day 

invoice_year,invoice_month,_ = get_month_int(df,'InvoiceMonth')
cohort_year,cohort_month,_ = get_month_int(df,'CohortMonth')

# Years Difference
year_diff = invoice_year - cohort_year 

# Months Difference
month_diff = invoice_month - cohort_month 

# Calculate Cohort Index
df['CohortIndex'] = year_diff * 12 + month_diff + 1 

#Count monthly active customers from each cohort
grouping = df.groupby(['CohortMonth', 'CohortIndex'])
cohort_data = grouping['CustomerID'].apply(pd.Series.nunique)

# Return number of unique elements in the object.
cohort_data = cohort_data.reset_index()
cohort_counts = cohort_data.pivot(index='CohortMonth',columns='CohortIndex',values='CustomerID')

# Retention table
cohort_size = cohort_counts.iloc[:,0]
retention = cohort_counts.divide(cohort_size,axis=0) # axis=0 to ensure the divide along the row axis 
retention.round(3) * 100 #to show the number as percentage

import matplotlib.pyplot as plt
import seaborn as sns
#Build the heatmap
plt.figure(figsize=(15, 8))
plt.title('Retention rates')
sns.heatmap(data=retention,annot = True,fmt = '.0%',vmin = 0.0,vmax = 0.5,cmap="BuPu_r")
plt.show()

# %%
#Average quantity for each cohort
grouping = df.groupby(['CohortMonth', 'CohortIndex'])
cohort_data = grouping['Quantity'].mean()
cohort_data = cohort_data.reset_index()
average_quantity = cohort_data.pivot(index='CohortMonth',columns='CohortIndex',values='Quantity')
average_quantity.round(1)
average_quantity.index = average_quantity.index.date

#Build the heatmap
plt.figure(figsize=(15, 8))
plt.title('Average quantity for each cohort')
sns.heatmap(data=average_quantity,annot = True,vmin = 0.0,vmax =20,cmap="BuGn_r")
plt.show()
